# %% [markdown]
# ## EDA

# %%
import obonet
# download the obo file
graph = obonet.read_obo("go-basic.obo")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from goatools import obo_parser
#
# ModuleNotFoundError: No module named 'goatools'

# %% [markdown]
# ## Pre-Processing and Transforms

# %% [markdown]
# ## MODELS

# %% [markdown]
# ## VALIDATION
